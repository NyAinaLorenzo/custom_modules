# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/4uldhv32qskguhwuydy5akk55ca4aa')

# %%
from smartpredict import api

dataset = api.dataset_save(dataset=df, name='flipu',
                           dataset_type='csv')
